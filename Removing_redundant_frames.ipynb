# %%
from cleanvision import Imagelab

# Path to your dataset, you can specify your own dataset path
dataset_path = "/home/areebadnan/Areeb_code/work/Visua_Data/output_videos/65ae82fb939a1d114f107f72/images"

# Initialize imagelab with your dataset
imagelab = Imagelab(data_path=dataset_path)

# Find issues
imagelab.find_issues()
imagelab.report()
# Out:
# Reading images from /home/areebadnan/Areeb_code/work/Visua_Data/output_videos/65ae82fb939a1d114f107f72/images
# Checking for dark, light, odd_aspect_ratio, low_information, exact_duplicates, near_duplicates, blurry, grayscale, odd_size images ...
# 100%|██████████| 124/124 [00:02<00:00, 41.70it/s]
# 100%|██████████| 124/124 [00:00<00:00, 174.36it/s]
# Issue checks completed. 50 issues found in the dataset. To see a detailed report of issues found, use imagelab.report().
# Issues found in images in order of severity in the dataset
#
# |    | issue_type       |   num_images |
# |---:|:-----------------|-------------:|
# |  0 | near_duplicates  |           50 |
# |  1 | dark             |            0 |
# |  2 | light            |            0 |
# |  3 | odd_aspect_ratio |            0 |
# |  4 | low_information  |            0 |
# |  5 | blurry           |            0 |
# |  6 | grayscale        |            0 |
# |  7 | odd_size         |            0 |
# |  8 | exact_duplicates |            0 |
#
# ------------------ near_duplicates images ------------------
#
# Number of examples with this issue: 50
# Examples representing most severe instances of this issue:
#
# Set: 0
# Set: 1
# Set: 2
# Set: 3

# %%
imagelab.issue_summary
# Out:
#          issue_type  num_images
# 0   near_duplicates          50
# 1              dark           0
# 2             light           0
# 3  odd_aspect_ratio           0
# 4   low_information           0
# 5            blurry           0
# 6         grayscale           0
# 7          odd_size           0
# 8  exact_duplicates           0

# %%
imagelab.issues
# Out:
#                                                     odd_size_score  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...             1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...             1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...             1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...             1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...             1.0
# ...                                                            ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...             1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...             1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...             1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...             1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...             1.0
#
#                                                     is_odd_size_issue  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...              False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...              False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...              False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...              False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...              False
# ...                                                               ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...              False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...              False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...              False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...              False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...              False
#
#                                                     odd_aspect_ratio_score  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                  0.5625
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                  0.5625
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                  0.5625
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                  0.5625
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                  0.5625
# ...                                                                    ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                  0.5625
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                  0.5625
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                  0.5625
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                  0.5625
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                  0.5625
#
#                                                     is_odd_aspect_ratio_issue  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# ...                                                                       ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
#
#                                                     low_information_score  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               0.863312
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               0.867418
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               0.870222
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               0.870230
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               0.870015
# ...                                                                   ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               0.818066
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               0.817592
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               0.818677
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               0.818283
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               0.819224
#
#                                                     is_low_information_issue  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# ...                                                                      ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
#
#                                                     light_score  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...     0.931157
# /home/areebadnan/Areeb_code/work/Visua_Data/out...     0.934985
# /home/areebadnan/Areeb_code/work/Visua_Data/out...     0.941421
# /home/areebadnan/Areeb_code/work/Visua_Data/out...     0.941445
# /home/areebadnan/Areeb_code/work/Visua_Data/out...     0.948715
# ...                                                         ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...     0.917693
# /home/areebadnan/Areeb_code/work/Visua_Data/out...     0.917817
# /home/areebadnan/Areeb_code/work/Visua_Data/out...     0.920010
# /home/areebadnan/Areeb_code/work/Visua_Data/out...     0.921068
# /home/areebadnan/Areeb_code/work/Visua_Data/out...     0.921653
#
#                                                     is_light_issue  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...           False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...           False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...           False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...           False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...           False
# ...                                                            ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...           False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...           False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...           False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...           False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...           False
#
#                                                     grayscale_score  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                1
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                1
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                1
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                1
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                1
# ...                                                             ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                1
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                1
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                1
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                1
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                1
#
#                                                     is_grayscale_issue  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               False
# ...                                                                ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...               False
#
#                                                     dark_score  is_dark_issue  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...    0.857190          False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...    0.863819          False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...    0.871408          False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...    0.871408          False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...    0.881201          False
# ...                                                        ...            ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...    0.942610          False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...    0.942338          False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...    0.941215          False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...    0.941129          False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...    0.941325          False
#
#                                                     blurry_score  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...      0.513330
# /home/areebadnan/Areeb_code/work/Visua_Data/out...      0.514526
# /home/areebadnan/Areeb_code/work/Visua_Data/out...      0.523660
# /home/areebadnan/Areeb_code/work/Visua_Data/out...      0.523672
# /home/areebadnan/Areeb_code/work/Visua_Data/out...      0.512525
# ...                                                          ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...      0.396575
# /home/areebadnan/Areeb_code/work/Visua_Data/out...      0.395757
# /home/areebadnan/Areeb_code/work/Visua_Data/out...      0.396248
# /home/areebadnan/Areeb_code/work/Visua_Data/out...      0.397594
# /home/areebadnan/Areeb_code/work/Visua_Data/out...      0.393275
#
#                                                     is_blurry_issue  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...            False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...            False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...            False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...            False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...            False
# ...                                                             ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...            False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...            False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...            False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...            False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...            False
#
#                                                     exact_duplicates_score  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     1.0
# ...                                                                    ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     1.0
#
#                                                     is_exact_duplicates_issue  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# ...                                                                       ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      False
#
#                                                     near_duplicates_score  \
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                    1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                    1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                    0.5
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                    0.5
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                    1.0
# ...                                                                   ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                    1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                    1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                    1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                    1.0
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                    1.0
#
#                                                     is_near_duplicates_issue
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      True
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                      True
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# ...                                                                      ...
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
# /home/areebadnan/Areeb_code/work/Visua_Data/out...                     False
#
# [124 rows x 18 columns]
